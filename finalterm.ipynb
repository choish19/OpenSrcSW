# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

f = open("country_vaccinations.csv","r")
data = csv.reader(f, delimiter = ',')
header = next(data)

max = 0
max_date = ""
min = 99999999
min_date = ""
for row in data:
    if row[7] != "":
        tmp = float(row[7])
        if tmp > max:
            max = tmp
            max_date = row[2]
        if tmp < min:
            min = tmp
            min_date = row[2]
print("가장 많이 접종된 날",max_date)
print("가장 적게 접종된 날",min_date)
# Out:
# 가장 많이 접종된 날 2021-06-28
# 가장 적게 접종된 날 2021-01-28

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

f = open("country_vaccinations.csv","r")
data = csv.reader(f, delimiter = ',')
header = next(data)

pre_c = "Afghanistan"
list_v = {}
for row in data:
    if row[0] != pre_c:
        pre_c = row[0]
        for k in row[-3].split(','):
            if k in list_v:
                list_v[k] += 1
            else:
                list_v[k] = 1
k = list(list_v.keys())
v = list(list_v.values())

df = pd.DataFrame(v, index=k, columns=['접종 국가 수'])
df
# Out:
#                      접종 국가 수
# Oxford/AstraZeneca        64
#  Pfizer/BioNTech         145
#  Sinovac                  51
#  Sputnik V                58
#  Sinopharm/Beijing        84
# Moderna                   34
#  Oxford/AstraZeneca      118
# CanSino                    7
#  Moderna                  56
# Pfizer/BioNTech           12
# Johnson&Johnson           84
#  Novavax                  11
#  Sputnik Light             8
# Sinopharm/Beijing          5
# Covaxin                    7
#  Johnson&Johnson           4
#  Sinopharm/Wuhan           2
#  ZF2001                    3
# Abdala                     4
#  Soberana Plus             1
#  Soberana02                4
# COVIran Barekat            1
#  Covaxin                   2
#  FAKHRAVAC                 1
#  Razi Cov Pars             1
#  SpikoGen                  1
# QazVac                     1
# EpiVacCorona               2
# Medigen                    1
#  Turkovac                  1
#  QazVac                    1
